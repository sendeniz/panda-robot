# %%
import robotic as ry
import numpy as np
import random
import time
from bridgebuild_env import create_n_boxes
# this import the local manipulation.py .. to be integrated in robotic..
import manipulation as manip

# %% [markdown]
# ### Task Env: Bridge Builder

# %%
C = ry.Config()
C.addFile(ry.raiPath('scenarios/pandaSingle.g'))
n_boxes = 3
keep_dist_between = ["box1", "box2", "box3"]
C = create_n_boxes(C = C, N = n_boxes, position = 'fixed')

# remove so collision with wrist camera is ignored
C.delFrame("panda_collCameraWrist")

# for convenience, a few definitions:
qHome = C.getJointState()
gripper = "l_gripper";
palm = "l_palm";
box1 = "box1";
box2 = "box2";
box3 = "box3";
table = "table";
boxSize = C.frame(box1).getSize()

C.view()
# Out:
# 0

# %%
C.setJointState(qHome)
C.view_raise()

for l in range(100):
        box = np.random.choice([box1, box2, box3])
        qStart = C.getJointState()

        graspDirection = 'x' #random.choice(['y', 'z']) #'x' not possible: box too large
        placeDirection = 'z' #random.choice(['x', 'y', 'z', 'xNeg', 'yNeg', 'zNeg'])
        info = f'placement {l}: grasp {graspDirection} place {placeDirection}'
        print('===', info)

        M = manip.ManipulationModelling(C, info, helpers=[gripper])
        M.setup_pick_and_place_waypoints(gripper, box, homing_scale=1e-1)
        M.grasp_box(1., gripper, box, palm, graspDirection)
        print('place direction:', placeDirection)
        M.place_box(2., box, table, palm, placeDirection)
        M.no_collision([], palm, table)
        M.auto_pairwise_keep_dist([], keep_dist_between, margin = 0.07)
        # x, y, z, smooth - table size: array([2.5 , 2.5 , 0.1 , 0.02])
        # place inital block as chosen by np.random.choice at a random location
        M.target_relative_xy_position(2., gripper, table, [np.random.uniform(0.0, 0.5), np.random.uniform(0.0, 0.5)])
        ways = M.solve()

        if not M.feasible:
            continue

        M2 = M.sub_motion(0)
        # M = manip.ManipulationModelling(C, info, helpers=[gripper])
        # M.setup_point_to_point_motion(qStart, ways[0])
        M2.no_collision([.3,.7], palm, box)
        
        M2.retract([.0, .2], gripper, dist = .13)
        M2.approach([.8, 1.], gripper)
        M2.solve()
        if not M2.feasible:
            continue

        M3 = M.sub_motion(1)
        #manip.ManipulationModelling(C, info)
        # M.setup_point_to_point_motion(ways[0], ways[1])
        M3.no_collision([], table, box)

        M3.solve()
        if not M3.ret.feasible:
            continue

        M2.play(C)
        C.attach(gripper, box)
        M3.play(C)
        C.attach(table, box)

del M
# Out:
# === placement 0: grasp x place z
# place direction: z
#   -- feasible:placement 0: grasp x place z
#      { time: 0.02899, evals: 32, done: 1, feasible: 1, sos: 0.115417, f: 0, ineq: 3.13974e-06, eq: 0.0267142 }
#   -- feasible:sub_motion_0--placement 0: grasp x place z
#      { time: 0.124609, evals: 20, done: 1, feasible: 1, sos: 3.17957, f: 0, ineq: 2.65196e-07, eq: 0.475916 }
#   -- feasible:sub_motion_1--placement 0: grasp x place z
#      { time: 1.16362, evals: 183, done: 1, feasible: 1, sos: 0.209885, f: 0, ineq: 0.00120969, eq: 0.32483 }
# === placement 1: grasp x place z
# place direction: z
#   -- feasible:placement 1: grasp x place z
#      { time: 0.051027, evals: 27, done: 1, feasible: 1, sos: 0.0869552, f: 0, ineq: 1.02995e-05, eq: 0.0162298 }
#   -- feasible:sub_motion_0--placement 1: grasp x place z
#      { time: 0.150675, evals: 26, done: 1, feasible: 1, sos: 1.74471, f: 0, ineq: 3.58791e-07, eq: 0.317771 }
#   -- feasible:sub_motion_1--placement 1: grasp x place z
#      { time: 0.503505, evals: 102, done: 1, feasible: 1, sos: 0.476056, f: 0, ineq: 0.000340355, eq: 0.163385 }
# === placement 2: grasp x place z
# place direction: z
#   -- feasible:placement 2: grasp x place z
#      { time: 0.020267, evals: 19, done: 1, feasible: 1, sos: 0.0950353, f: 0, ineq: 1.22291e-08, eq: 0.00546589 }
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.153557, evals: 17, done: 1, feasible: 1, sos: 1.92925, f: 0, ineq: 5.42792e-07, eq: 0.15847 }
#   -- feasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.93444, evals: 161, done: 1, feasible: 1, sos: 0.48691, f: 0, ineq: 0.000307471, eq: 0.00296526 }
# === placement 3: grasp x place z
# place direction: z
#   -- feasible:placement 3: grasp x place z
#      { time: 0.021519, evals: 37, done: 1, feasible: 1, sos: 0.0461115, f: 0, ineq: 4.16944e-07, eq: 5.77767e-06 }
#   -- feasible:sub_motion_0--placement 3: grasp x place z
#      { time: 0.203144, evals: 39, done: 1, feasible: 1, sos: 1.11363, f: 0, ineq: 2.40898e-07, eq: 3.83126e-05 }
#   -- feasible:sub_motion_1--placement 3: grasp x place z
#      { time: 0.0565, evals: 9, done: 1, feasible: 1, sos: 0.0863323, f: 0, ineq: 0.000752275, eq: 0.00472382 }
# === placement 4: grasp x place z
# place direction: z
#   -- feasible:placement 4: grasp x place z
#      { time: 0.009536, evals: 16, done: 1, feasible: 1, sos: 0.0555527, f: 0, ineq: 3.9677e-08, eq: 2.30009e-06 }
#   -- feasible:sub_motion_0--placement 4: grasp x place z
#      { time: 0.193845, evals: 37, done: 1, feasible: 1, sos: 1.49988, f: 0, ineq: 5.36664e-07, eq: 4.21062e-05 }
#   -- feasible:sub_motion_1--placement 4: grasp x place z
#      { time: 0.051003, evals: 9, done: 1, feasible: 1, sos: 0.174046, f: 0, ineq: 0.000708055, eq: 0.00333819 }
# === placement 5: grasp x place z
# place direction: z
#   -- feasible:placement 5: grasp x place z
#      { time: 0.028693, evals: 40, done: 1, feasible: 1, sos: 0.05328, f: 0, ineq: 1.57967e-08, eq: 1.05524e-06 }
#   -- feasible:sub_motion_0--placement 5: grasp x place z
#      { time: 0.162025, evals: 33, done: 1, feasible: 1, sos: 1.02242, f: 0, ineq: 2.53861e-07, eq: 0.000749169 }
#   -- feasible:sub_motion_1--placement 5: grasp x place z
#      { time: 0.068117, evals: 10, done: 1, feasible: 1, sos: 0.194687, f: 0, ineq: 0.000804817, eq: 0.00448521 }
# === placement 6: grasp x place z
# place direction: z
#   -- feasible:placement 6: grasp x place z
#      { time: 0.106762, evals: 129, done: 1, feasible: 1, sos: 0.0488643, f: 0, ineq: 0.0189734, eq: 0.0761906 }
#   -- feasible:sub_motion_0--placement 6: grasp x place z
#      { time: 0.148549, evals: 31, done: 1, feasible: 1, sos: 1.7498, f: 0, ineq: 8.08444e-07, eq: 0.00456267 }
#   -- feasible:sub_motion_1--placement 6: grasp x place z
#      { time: 1.89537, evals: 200, done: 1, feasible: 1, sos: 0.202685, f: 0, ineq: 0.00600882, eq: 0.0937681 }
# === placement 7: grasp x place z
# place direction: z
#   -- feasible:placement 7: grasp x place z
#      { time: 0.029471, evals: 26, done: 1, feasible: 1, sos: 0.0839691, f: 0, ineq: 0.00220399, eq: 0.00370822 }
#   -- feasible:sub_motion_0--placement 7: grasp x place z
#      { time: 0.433215, evals: 68, done: 1, feasible: 1, sos: 3.98697, f: 0, ineq: 4.30828e-06, eq: 0.0127582 }
#   -- feasible:sub_motion_1--placement 7: grasp x place z
#      { time: 0.067818, evals: 8, done: 1, feasible: 1, sos: 0.35464, f: 0, ineq: 0.000708261, eq: 0.0019944 }
# === placement 8: grasp x place z
# place direction: z
#   -- feasible:placement 8: grasp x place z
#      { time: 0.025005, evals: 31, done: 1, feasible: 1, sos: 0.0427796, f: 0, ineq: 1.80907e-07, eq: 9.47998e-06 }
#   -- feasible:sub_motion_0--placement 8: grasp x place z
#      { time: 0.227952, evals: 49, done: 1, feasible: 1, sos: 0.881287, f: 0, ineq: 5.70532e-07, eq: 0.0001496 }
#   -- feasible:sub_motion_1--placement 8: grasp x place z
#      { time: 0.056903, evals: 8, done: 1, feasible: 1, sos: 0.0650372, f: 0, ineq: 0.000565569, eq: 0.00341884 }
# === placement 9: grasp x place z
# place direction: z
#   -- feasible:placement 9: grasp x place z
#      { time: 0.009761, evals: 10, done: 1, feasible: 1, sos: 0.0370725, f: 0, ineq: 8.17066e-08, eq: 3.0833e-06 }
#   -- feasible:sub_motion_0--placement 9: grasp x place z
#      { time: 0.208499, evals: 32, done: 1, feasible: 1, sos: 1.52499, f: 0, ineq: 6.35645e-07, eq: 0.000109397 }
#   -- feasible:sub_motion_1--placement 9: grasp x place z
#      { time: 0.058801, evals: 10, done: 1, feasible: 1, sos: 0.0347082, f: 0, ineq: 0.00025891, eq: 0.00260897 }
# === placement 10: grasp x place z
# place direction: z
#   -- feasible:placement 10: grasp x place z
#      { time: 0.080288, evals: 76, done: 1, feasible: 1, sos: 0.0489388, f: 0, ineq: 1.13679e-08, eq: 1.45167e-06 }
#   -- feasible:sub_motion_0--placement 10: grasp x place z
#      { time: 0.143871, evals: 26, done: 1, feasible: 1, sos: 1.03354, f: 0, ineq: 3.19739e-07, eq: 5.41392e-05 }
#   -- feasible:sub_motion_1--placement 10: grasp x place z
#      { time: 0.066819, evals: 9, done: 1, feasible: 1, sos: 0.165671, f: 0, ineq: 0.000443482, eq: 0.00351405 }
# === placement 11: grasp x place z
# place direction: z
#   -- feasible:placement 11: grasp x place z
#      { time: 0.140258, evals: 159, done: 1, feasible: 1, sos: 0.0585262, f: 0, ineq: 0.00137763, eq: 0.00485606 }
#   -- feasible:sub_motion_0--placement 11: grasp x place z
#      { time: 0.410864, evals: 40, done: 1, feasible: 1, sos: 2.67628, f: 0, ineq: 1.87047e-06, eq: 0.00765417 }
#   -- feasible:sub_motion_1--placement 11: grasp x place z
#      { time: 2.16626, evals: 200, done: 1, feasible: 1, sos: 0.0650241, f: 0, ineq: 0.00067392, eq: 0.00591068 }
# === placement 12: grasp x place z
# place direction: z
#   -- feasible:placement 12: grasp x place z
#      { time: 0.024364, evals: 19, done: 1, feasible: 1, sos: 0.0531574, f: 0, ineq: 6.16524e-09, eq: 5.57491e-07 }
#   -- feasible:sub_motion_0--placement 12: grasp x place z
#      { time: 0.179203, evals: 31, done: 1, feasible: 1, sos: 2.32437, f: 0, ineq: 1.56993e-06, eq: 2.71344e-05 }
#   -- feasible:sub_motion_1--placement 12: grasp x place z
#      { time: 0.035287, evals: 9, done: 1, feasible: 1, sos: 0.178358, f: 0, ineq: 0.000121705, eq: 0.00215881 }
# === placement 13: grasp x place z
# place direction: z
#   -- infeasible:placement 13: grasp x place z
#      { time: 0.137506, evals: 189, done: 1, feasible: 0, sos: 0.241159, f: 0, ineq: 0.679982, eq: 0.633641 }
# === placement 14: grasp x place z
# place direction: z
#   -- feasible:placement 14: grasp x place z
#      { time: 0.01068, evals: 19, done: 1, feasible: 1, sos: 0.0324496, f: 0, ineq: 4.15514e-07, eq: 1.10113e-05 }
#   -- feasible:sub_motion_0--placement 14: grasp x place z
#      { time: 0.10062, evals: 35, done: 1, feasible: 1, sos: 0.855147, f: 0, ineq: 3.07443e-07, eq: 0.00108911 }
#   -- feasible:sub_motion_1--placement 14: grasp x place z
#      { time: 0.039203, evals: 10, done: 1, feasible: 1, sos: 0.0436427, f: 0, ineq: 0.000278879, eq: 0.00253859 }
# === placement 15: grasp x place z
# place direction: z
#   -- feasible:placement 15: grasp x place z
#      { time: 0.025855, evals: 20, done: 1, feasible: 1, sos: 0.0332686, f: 0, ineq: 1.38861e-09, eq: 2.11218e-07 }
#   -- feasible:sub_motion_0--placement 15: grasp x place z
#      { time: 0.108818, evals: 32, done: 1, feasible: 1, sos: 1.17458, f: 0, ineq: 4.1946e-07, eq: 0.00127007 }
#   -- feasible:sub_motion_1--placement 15: grasp x place z
#      { time: 0.051341, evals: 10, done: 1, feasible: 1, sos: 0.0598314, f: 0, ineq: 0.000492302, eq: 0.00344415 }
# === placement 16: grasp x place z
# place direction: z
#   -- feasible:placement 16: grasp x place z
#      { time: 0.121543, evals: 157, done: 1, feasible: 1, sos: 0.0953221, f: 0, ineq: 4.27128e-08, eq: 2.07073e-06 }
#   -- feasible:sub_motion_0--placement 16: grasp x place z
#      { time: 0.079247, evals: 18, done: 1, feasible: 1, sos: 2.68978, f: 0, ineq: 3.06754e-07, eq: 0.00108442 }
#   -- feasible:sub_motion_1--placement 16: grasp x place z
#      { time: 0.046306, evals: 8, done: 1, feasible: 1, sos: 0.262937, f: 0, ineq: 0.000361656, eq: 0.00358841 }
# === placement 17: grasp x place z
# place direction: z
#   -- feasible:placement 17: grasp x place z
#      { time: 0.037471, evals: 31, done: 1, feasible: 1, sos: 0.0519885, f: 0, ineq: 4.19869e-05, eq: 0.0015884 }
#   -- feasible:sub_motion_0--placement 17: grasp x place z
#      { time: 0.17076, evals: 36, done: 1, feasible: 1, sos: 1.96541, f: 0, ineq: 1.56052e-06, eq: 0.00358051 }
#   -- feasible:sub_motion_1--placement 17: grasp x place z
#      { time: 0.861433, evals: 138, done: 1, feasible: 1, sos: 0.232609, f: 0, ineq: 0.00035653, eq: 0.00338237 }
# === placement 18: grasp x place z
# place direction: z
#   -- feasible:placement 18: grasp x place z
#      { time: 0.057646, evals: 22, done: 1, feasible: 1, sos: 0.0760094, f: 0, ineq: 1.81612e-07, eq: 5.12484e-06 }
#   -- feasible:sub_motion_0--placement 18: grasp x place z
#      { time: 0.122657, evals: 31, done: 1, feasible: 1, sos: 1.14912, f: 0, ineq: 6.07333e-07, eq: 0.000180259 }
#   -- feasible:sub_motion_1--placement 18: grasp x place z
#      { time: 0.03427, evals: 8, done: 1, feasible: 1, sos: 0.299887, f: 0, ineq: 0.000584124, eq: 0.00196788 }
# === placement 19: grasp x place z
# place direction: z
#   -- feasible:placement 19: grasp x place z
#      { time: 0.01707, evals: 12, done: 1, feasible: 1, sos: 0.0422507, f: 0, ineq: 2.54889e-07, eq: 7.59275e-06 }
#   -- feasible:sub_motion_0--placement 19: grasp x place z
#      { time: 0.212504, evals: 46, done: 1, feasible: 1, sos: 1.06488, f: 0, ineq: 8.03983e-07, eq: 0.000186754 }
#   -- feasible:sub_motion_1--placement 19: grasp x place z
#      { time: 0.021034, evals: 6, done: 1, feasible: 1, sos: 0.0308991, f: 0, ineq: 0.000302519, eq: 0.00234642 }
# === placement 20: grasp x place z
# place direction: z
#   -- feasible:placement 20: grasp x place z
#      { time: 0.02453, evals: 10, done: 1, feasible: 1, sos: 0.0316393, f: 0, ineq: 5.55118e-08, eq: 1.97645e-06 }
#   -- feasible:sub_motion_0--placement 20: grasp x place z
#      { time: 0.118116, evals: 26, done: 1, feasible: 1, sos: 0.950618, f: 0, ineq: 3.49833e-07, eq: 0.000909554 }
#   -- feasible:sub_motion_1--placement 20: grasp x place z
#      { time: 0.040148, evals: 8, done: 1, feasible: 1, sos: 0.0377139, f: 0, ineq: 0.000277212, eq: 0.00259157 }
# === placement 21: grasp x place z
# place direction: z
#   -- feasible:placement 21: grasp x place z
#      { time: 0.011299, evals: 19, done: 1, feasible: 1, sos: 0.0645062, f: 0, ineq: 2.65708e-07, eq: 1.46051e-05 }
#   -- feasible:sub_motion_0--placement 21: grasp x place z
#      { time: 0.164238, evals: 38, done: 1, feasible: 1, sos: 1.21879, f: 0, ineq: 1.01305e-07, eq: 0.000167852 }
#   -- feasible:sub_motion_1--placement 21: grasp x place z
#      { time: 0.042793, evals: 8, done: 1, feasible: 1, sos: 0.117483, f: 0, ineq: 0.000225751, eq: 0.00264065 }
# === placement 22: grasp x place z
# place direction: z
#   -- feasible:placement 22: grasp x place z
#      { time: 0.020138, evals: 37, done: 1, feasible: 1, sos: 0.0396345, f: 0, ineq: 3.13124e-09, eq: 2.74624e-06 }
#   -- feasible:sub_motion_0--placement 22: grasp x place z
#      { time: 0.088297, evals: 21, done: 1, feasible: 1, sos: 0.975244, f: 0, ineq: 2.94805e-07, eq: 4.98156e-05 }
#   -- feasible:sub_motion_1--placement 22: grasp x place z
#      { time: 0.041318, evals: 9, done: 1, feasible: 1, sos: 0.110676, f: 0, ineq: 0.000474292, eq: 0.00316064 }
# === placement 23: grasp x place z
# place direction: z
#   -- feasible:placement 23: grasp x place z
#      { time: 0.017637, evals: 23, done: 1, feasible: 1, sos: 0.0372508, f: 0, ineq: 3.05957e-09, eq: 3.47131e-07 }
#   -- feasible:sub_motion_0--placement 23: grasp x place z
#      { time: 0.145785, evals: 23, done: 1, feasible: 1, sos: 1.81605, f: 0, ineq: 8.05588e-07, eq: 0.000193898 }
#   -- feasible:sub_motion_1--placement 23: grasp x place z
#      { time: 1.21117, evals: 201, done: 1, feasible: 1, sos: 0.097221, f: 0, ineq: 0.000513899, eq: 0.00570806 }
# === placement 24: grasp x place z
# place direction: z
#   -- feasible:placement 24: grasp x place z
#      { time: 0.132912, evals: 201, done: 1, feasible: 1, sos: 0.044295, f: 0, ineq: 0.122035, eq: 0.118964 }
#   -- feasible:sub_motion_0--placement 24: grasp x place z
#      { time: 0.189596, evals: 19, done: 1, feasible: 1, sos: 1.93368, f: 0, ineq: 2.88545e-07, eq: 0.000285048 }
#   -- feasible:sub_motion_1--placement 24: grasp x place z
#      { time: 0.244916, evals: 23, done: 1, feasible: 1, sos: 0.0980706, f: 0, ineq: 0, eq: 0.0211063 }
# === placement 25: grasp x place z
# place direction: z
#   -- feasible:placement 25: grasp x place z
#      { time: 0.011136, evals: 18, done: 1, feasible: 1, sos: 0.039972, f: 0, ineq: 0.0114499, eq: 0.0135137 }
#   -- feasible:sub_motion_0--placement 25: grasp x place z
#      { time: 0.313341, evals: 63, done: 1, feasible: 1, sos: 1.61113, f: 0, ineq: 2.31253e-06, eq: 0.000206648 }
#   -- feasible:sub_motion_1--placement 25: grasp x place z
#      { time: 0.071131, evals: 9, done: 1, feasible: 1, sos: 0.028237, f: 0, ineq: 0.000450864, eq: 0.00339033 }
# === placement 26: grasp x place z
# place direction: z
#   -- feasible:placement 26: grasp x place z
#      { time: 0.019214, evals: 24, done: 1, feasible: 1, sos: 0.0339283, f: 0, ineq: 5.99311e-09, eq: 1.30109e-07 }
#   -- feasible:sub_motion_0--placement 26: grasp x place z
#      { time: 0.173602, evals: 24, done: 1, feasible: 1, sos: 1.79141, f: 0, ineq: 1.39345e-06, eq: 0.000184151 }
#   -- feasible:sub_motion_1--placement 26: grasp x place z
#      { time: 0.063262, evals: 7, done: 1, feasible: 1, sos: 0.018935, f: 0, ineq: 0.000341886, eq: 0.00294937 }
# === placement 27: grasp x place z
# place direction: z
#   -- infeasible:placement 27: grasp x place z
#      { time: 0.080205, evals: 92, done: 1, feasible: 0, sos: 0.0476386, f: 0, ineq: 0.388721, eq: 0.538906 }
# === placement 28: grasp x place z
# place direction: z
#   -- feasible:placement 28: grasp x place z
#      { time: 0.024708, evals: 46, done: 1, feasible: 1, sos: 0.0668106, f: 0, ineq: 1.25051e-07, eq: 3.85071e-06 }
#   -- feasible:sub_motion_0--placement 28: grasp x place z
#      { time: 0.114384, evals: 25, done: 1, feasible: 1, sos: 1.63639, f: 0, ineq: 5.67958e-07, eq: 8.27221e-05 }
#   -- feasible:sub_motion_1--placement 28: grasp x place z
#      { time: 0.06059, evals: 10, done: 1, feasible: 1, sos: 0.202506, f: 0, ineq: 0.000110363, eq: 0.00200872 }
# === placement 29: grasp x place z
# place direction: z
#   -- feasible:placement 29: grasp x place z
#      { time: 0.129306, evals: 201, done: 1, feasible: 1, sos: 0.0646216, f: 0, ineq: 0.140532, eq: 0.339651 }
#   -- feasible:sub_motion_0--placement 29: grasp x place z
#      { time: 0.144017, evals: 46, done: 1, feasible: 1, sos: 1.15111, f: 0, ineq: 8.62631e-07, eq: 0.000279702 }
#   -- feasible:sub_motion_1--placement 29: grasp x place z
#      { time: 0.087993, evals: 21, done: 1, feasible: 1, sos: 0.179522, f: 0, ineq: 0.000522566, eq: 0.0530747 }
# === placement 30: grasp x place z
# place direction: z
#   -- infeasible:placement 30: grasp x place z
#      { time: 0.060735, evals: 86, done: 1, feasible: 0, sos: 0.118053, f: 0, ineq: 0.908791, eq: 0.401031 }
# === placement 31: grasp x place z
# place direction: z
#   -- feasible:placement 31: grasp x place z
#      { time: 0.012647, evals: 22, done: 1, feasible: 1, sos: 0.0467429, f: 0, ineq: 0.433544, eq: 6.52033e-07 }
#   -- feasible:sub_motion_0--placement 31: grasp x place z
#      { time: 0.235459, evals: 40, done: 1, feasible: 1, sos: 1.52163, f: 0, ineq: 0, eq: 0.000111864 }
#   -- feasible:sub_motion_1--placement 31: grasp x place z
#      { time: 0.071764, evals: 11, done: 1, feasible: 1, sos: 0.0230443, f: 0, ineq: 0.00038799, eq: 0.00312898 }
# === placement 32: grasp x place z
# place direction: z
#   -- feasible:placement 32: grasp x place z
#      { time: 0.123753, evals: 188, done: 1, feasible: 1, sos: 0.076775, f: 0, ineq: 0.297008, eq: 0.336239 }
#   -- feasible:sub_motion_0--placement 32: grasp x place z
#      { time: 0.231018, evals: 48, done: 1, feasible: 1, sos: 3.64795, f: 0, ineq: 0, eq: 0.0764899 }
#   -- feasible:sub_motion_1--placement 32: grasp x place z
#      { time: 0.219381, evals: 34, done: 1, feasible: 1, sos: 0.471615, f: 0, ineq: 0.000207039, eq: 0.00272222 }
# === placement 33: grasp x place z
# place direction: z
#   -- feasible:placement 33: grasp x place z
#      { time: 0.045945, evals: 87, done: 1, feasible: 1, sos: 0.0411525, f: 0, ineq: 0.0716798, eq: 0.107908 }
#   -- feasible:sub_motion_0--placement 33: grasp x place z
#      { time: 0.11641, evals: 33, done: 1, feasible: 1, sos: 0.906879, f: 0, ineq: 3.16899e-07, eq: 0.0349273 }
#   -- feasible:sub_motion_1--placement 33: grasp x place z
#      { time: 0.182283, evals: 47, done: 1, feasible: 1, sos: 0.0285715, f: 0, ineq: 0.0136412, eq: 0.291389 }
