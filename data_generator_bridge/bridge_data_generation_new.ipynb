# %%
import os
import numpy as np
import robotic as ry
import manipulation as manip
import matplotlib.pyplot as plt
import shutil
from utils import sample_arena
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
gripper = "l_gripper"
palm = "l_palm"
boxes = [f"box{i}" for i in range(1, 4)]
table = "table"

# %%
def scene_generator():
    C = ry.Config()
    C.addFile(ry.raiPath("scenarios/pandaSingleWithTopCamera.g"))

    for i in range(3):
        # Frame name
        box_name = f"box{i+1}"

        # Box color
        color = [0, 0, 0]
        color[i] = 1

        # Position
        position_val1 = 0.2 * i + .3

        C.addFrame(box_name) \
            .setPosition([position_val1, 0.05, 0.72]) \
            .setShape(ry.ST.ssBox, size=[0.04, 0.04, 0.12, 0.001]) \
            .setColor(color) \
            .setContact(1) \
            .setMass(.1)
        

    C.delFrame("panda_collCameraWrist")

    A = .4
    B = .35
    OFFSET = [0, .2]

    for i in range(1,4):        
        x_y_pos = sample_arena(A, B, OFFSET)[:2]
        x_y_pos.append(.72)
        C.getFrame(f"box{i}").setPosition(x_y_pos)

    return C

# %%
def path_generator(C: ry.Config, target_position: np.ndarray):
	boxes = ["box1", "box2", "box3"]
	
	# Pick place waypoints
	M = manip.ManipulationModelling()
	M.setup_pick_and_place_sequence(C, gripper, table, boxes)

	# Box 1
	grasp_direction = np.random.choice(["x", "y"])
	M.grasp_box(1., gripper, "box1", palm, grasp_direction)
	M.place_box(2., "box1", table, palm, "z")
	M.target_relative_xy_position(2., "box1", table, target_position)

	# Box 2
	grasp_direction = np.random.choice(["x", "y"])
	M.grasp_box(3., gripper, "box2", palm, grasp_direction)
	M.place_box(4., "box2", table, palm, "z")
	M.set_relative_distance(4., "box1", "box2", .05)

	M.solve(verbose=0)
	if not M.feasible: return False, []
	
	# Sub motions
	paths = []
	for i, box in enumerate(boxes[:2]):
		idx = i*2
		M1 = M.sub_motion(idx, accumulated_collisions=True)
		M1.retract([.0, .2], gripper)
		M1.approach([.8, 1.], gripper)
		path = M1.solve(verbose=0)
		if not M1.feasible:
			return False, []
		paths.append(path)

		M2 = M.sub_motion(idx+1, accumulated_collisions=True)
		path = M2.solve(verbose=0)
		if not M2.feasible:
			return False, []
		paths.append(path)

	return True, paths

# %%
def capture_data2(C: ry.Config, paths: np.ndarray, ep_idx: int, states_prev, actions_prev, timestep_count_prev):
    C.view()
    C.view_setCamera(C.getFrame("topCamera"))

    im_path = f"./bridge_/{ep_idx}/images"
    if not os.path.exists(im_path):
        os.makedirs(im_path)
    
    timestep_count = timestep_count_prev
    grasping_value = 0
    states = []
    actions = []
    C.setJointState(paths[0][0])
    for i, path in enumerate(paths):
        for j in range(1, len(path)):

            timestep_count += 1

            C.view()
            image = C.view_getRgb()
            plt.imsave(f"{im_path}/{timestep_count}.png", image)
            
            state = path[j-1]
            action = path[j]

            states.append([*state, grasping_value])
            actions.append([*action, grasping_value])

            C.setJointState(path[j])

        if i%2:
            C.attach(table, boxes[2])
            grasping_value = 0
        else:
            C.attach(gripper, boxes[2])
            grasping_value = 1

    states = np.concatenate((states_prev,np.array(states)))
    actions = np.concatenate((actions_prev, np.array(actions_prev)))
    np.save(f"./bridge_/{ep_idx}/state", states)
    np.save(f"./bridge_/{ep_idx}/actions", actions)

# %%
def path_generator2(C: ry.Config, target_position: np.ndarray, grasp_direction="x"):
	boxes = ["box3"]
	
	delta=(C.getFrame("box2").getPosition()-C.getFrame("box1").getPosition())
	delta/=np.linalg.norm(delta)

	C.addFrame("box4") \
            .setPosition((C.getFrame("box1").getPosition()+C.getFrame("box2").getPosition())/2) \
            .setShape(ry.ST.ssBox, size=[0.04, 0.04, 0.12, 0.001]) \
            .setColor([0,0,0,0]) \
            .setContact(0) \
            # .setMass(.1)
	# Pick place waypoints
	M = manip.ManipulationModelling()
	M.setup_pick_and_place_sequence(C, gripper, table, boxes)
	
	# Box 3
	place_direction = "x" if grasp_direction == "y" else "y"
	M.grasp_box(1., gripper, "box3", palm, grasp_direction)
	M.place_box(2., "box3", "box4", palm, place_direction)
	M.komo.addObjective([2], ry.FS.vectorY, [gripper], ry.OT.eq, target=delta)
	# M.set_relative_distance(6., "box3", "box2", .0)

	M.solve(verbose=0)
	if not M.feasible: return False, []
	
	# Sub motions
	paths = []
	M1 = M.sub_motion(0, accumulated_collisions=True)
	M1.retract([.0, .2], gripper)
	M1.approach([.8, 1.], gripper)
	path = M1.solve(verbose=0)
	if not M1.feasible:
		return False, []
	paths.append(path)

	M2 = M.sub_motion(1, accumulated_collisions=True)
	path = M2.solve(verbose=0)
	if not M2.feasible:
		return False, []
	paths.append(path)

    
	return True, paths

# %%
def capture_data(C: ry.Config, paths: np.ndarray, ep_idx: int):
    C.view()
    C.view_setCamera(C.getFrame("topCamera"))

    im_path = f"./bridge_/{ep_idx}/images"
    if not os.path.exists(im_path):
        os.makedirs(im_path)
    
    timestep_count = 0
    grasping_value = 0
    states = []
    actions = []
    C.setJointState(paths[0][0])
    for i, path in enumerate(paths):
        for j in range(1, len(path)):

            timestep_count += 1

            C.view()
            image = C.view_getRgb()
            plt.imsave(f"{im_path}/{timestep_count}.png", image)
            
            state = path[j-1]
            action = path[j]

            states.append([*state, grasping_value])
            actions.append([*action, grasping_value])

            C.setJointState(path[j])

        if i%2:
            C.attach(table, boxes[i//2])
            grasping_value = 0
        else:
            C.attach(gripper, boxes[i//2])
            grasping_value = 1

    states = np.array(states)
    actions = np.array(actions)
    return states, actions, timestep_count

# %%
MAX_EPISODE_COUNT = 300
episode_count = 0
for i in range(MAX_EPISODE_COUNT):
	attempt_count = 10
	midpoint = [-0.105, 0.4, 0.745]

	C = scene_generator()

	for l in range(attempt_count):
		housePosition = [midpoint[0] + np.random.random()*.2 -.1, midpoint[1] + np.random.random()*.2]
		success, paths = path_generator(C, housePosition)
		
		if success:
			episode_count += 1
			print(f"Saving_episode {episode_count}... ", end="")
			states, actions, timestep = capture_data(C, paths, episode_count)
			print("Done!")
		success_new, paths = path_generator2(C, housePosition)

		if not success_new:
			success_new, paths = path_generator2(C, housePosition, "y")
			print(success_new)

		if success and success_new:
			print(f"Saving_episode {episode_count}... ", end="")
			capture_data2(C, paths, episode_count, states, actions, timestep)
			print("Done!")
			break
		elif not success_new and success:
			print(f"Deleting episode {episode_count}... ", end="")

			shutil.rmtree(f"bridge_/{episode_count}")
			episode_count -= 1
	del C
# Out:
# Saving_episode 1... Done!
# False-- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
#
# Deleting episode 1... Saving_episode 1... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 1... Saving_episode 1... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 1... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 1... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 1... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 1... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 1... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 1... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 1... Saving_episode 1... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 1... Saving_episode 1... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 1... Saving_episode 1... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 1... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 1... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 1... Saving_episode 1... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 1... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 1... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 1... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 1... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 1... Done!
# Saving_episode 2... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 2... Saving_episode 2... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 2... Done!
# Saving_episode 3... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 3... Done!
# False-- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
#
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 4... Done!
# Saving_episode 4... Done!
# Saving_episode 5... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 5... Done!
# Saving_episode 6... Done!
# Saving_episode 6... Done!
# Saving_episode 7... Done!
# Saving_episode 7... Done!
# False-- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
#
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 8... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 8... Done!
# Saving_episode 9... Done!
# False
# Deleting episode 9... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 9... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 9... Done!
# Saving_episode 10... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 10... Done!
# Saving_episode 11... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 11... Done!
# Saving_episode 12... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 12... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False-- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
#
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 13... Done!
# False
# Deleting episode 13... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 13... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 13... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 14... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 14... Saving_episode 14... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 14... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!False
#
# Saving_episode 14... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 14... Saving_episode 14... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 14... Saving_episode 14... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 14... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 14... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 14... Saving_episode 14... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 14... Done!
# Saving_episode 15... Done!
# Saving_episode 15... Done!
# Saving_episode 16... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!False
# Deleting episode 16...
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 16... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 16... Saving_episode 16... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 16... Saving_episode 16... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 16... Saving_episode 16... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 16... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 16... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 16... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Done!
# Saving_episode 17... Done!
# Saving_episode 17... Done!
# Saving_episode 18... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 18... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 18... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 18... Done!
# Saving_episode 19... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 19... Saving_episode 19... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 19... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 19... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 19... Done!
# Saving_episode 20... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 20... Done!
# Saving_episode 21... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 21... Done!
# Saving_episode 22... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 22... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 22... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!False
# Deleting episode 22...
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 22... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 22... Saving_episode 22... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 22... Saving_episode 22... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 22... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 22... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 22... Done!
# Saving_episode 23... Done!
# Saving_episode 23... Done!
# Saving_episode 24... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 24... Saving_episode 24... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 24... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 24... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 24... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 25... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 25... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!False
#
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 26... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 26... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False-- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
#
# Saving_episode 27... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 27... Done!
# Saving_episode 28... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 28... Done!
# Saving_episode 29... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 29... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 29... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 29... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 29... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 29... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Done!
# Saving_episode 30... Done!
# Saving_episode 30... Done!
# Saving_episode 31... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 31... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 31... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 31... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 31... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 31... Saving_episode 31... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 31... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 31... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 31... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 31... Done!
# Saving_episode 31... Done!
# Saving_episode 32... Done!
# Saving_episode 32... Done!
# Saving_episode 33... Done!
# Saving_episode 33... Done!
# Saving_episode 34... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 34... Done!
# Saving_episode 35... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 35... Done!
# Saving_episode 36... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 36... Saving_episode 36... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!Saving_episode 36...
# Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!False
#
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 37... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 37... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 37... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 37... Done!
# Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 38... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 38... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 39... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 39... Saving_episode 39... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 39... Done!
# Saving_episode 40... Done!
# Saving_episode 40... Done!
# Saving_episode 41... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 41... Done!
# Saving_episode 42... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 42... Done!
# Saving_episode 43... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 43... Done!
# Saving_episode 44... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 44... Done!
# Saving_episode 45... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 45... Saving_episode 45... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 45... Done!
# False-- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
#
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!False
#
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False-- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
#
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False-- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
#
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 46... Done!
# Saving_episode 46... Done!
# Saving_episode 47... Done!
# Saving_episode 47... Done!
# Saving_episode 48... Done!
# Saving_episode 48... Done!
# Saving_episode 49... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 49... Done!
# Saving_episode 50... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!False
# Deleting episode 50...
# Saving_episode 50... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 50... Saving_episode 50... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 50... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...Saving_episode 50...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 50... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False-- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
#
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 50... Done!
# Saving_episode 50... Done!
# Saving_episode 51... Done!
# Saving_episode 51... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 52... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 52... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 52... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# ...
# False
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!False
#
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 223... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 223... Saving_episode 223... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 223... Saving_episode 223... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 223... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 223... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 223... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 223... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 223... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 223... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 223... Saving_episode 223... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 223... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 223... Done!
# Saving_episode 223... Done!
# Saving_episode 224... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 224... Saving_episode 224... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 224... Done!
# Saving_episode 225... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 225... Done!
# Saving_episode 226... Done!
# Saving_episode 226... Done!
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!False
# Deleting episode 227...
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... Saving_episode 227... Done!
# False
# Deleting episode 227... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!False
# Deleting episode 227...
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 227... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 227... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 227... Done!
# Saving_episode 228... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 228... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 228... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 228... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Saving_episode 228... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 228... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 228... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# Deleting episode 228... -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# False
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# Saving_episode 228... Done!
# -- WARNING:kin.cpp:addFrame:195(-1) frame already exists! returning existing without modifications!
# True
# Saving_episode 228... Done!
